# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=1000, n_features=2, centers=4, cluster_std=1.8, random_state=70)

# %%
plt.figure(figsize=(12,8))
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.6469027 ,  8.14571687],
#        [-3.59512826, -6.82278233],
#        [ 8.65078131,  7.28034592],
#        [ 6.8437778 , -1.36122986]])

# %%
kmeans.labels_
# Out:
# array([2, 2, 0, 2, 3, 1, 3, 2, 0, 2, 1, 3, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1,
#        0, 2, 2, 2, 3, 1, 2, 0, 2, 3, 0, 3, 3, 2, 0, 1, 2, 3, 2, 2, 2, 3,
#        0, 1, 2, 1, 0, 2, 3, 0, 1, 0, 0, 2, 0, 0, 0, 1, 0, 0, 0, 2, 3, 2,
#        2, 3, 2, 0, 3, 3, 1, 3, 2, 3, 0, 0, 1, 3, 3, 3, 2, 2, 3, 1, 2, 0,
#        0, 3, 1, 0, 1, 0, 3, 1, 2, 3, 2, 3, 1, 2, 2, 0, 3, 2, 2, 3, 1, 2,
#        0, 3, 1, 1, 2, 2, 1, 0, 3, 1, 1, 3, 3, 3, 2, 2, 3, 0, 2, 3, 0, 3,
#        0, 1, 0, 0, 3, 0, 1, 1, 2, 3, 3, 2, 1, 1, 3, 0, 2, 3, 3, 2, 1, 0,
#        3, 0, 2, 3, 2, 1, 1, 1, 2, 2, 3, 3, 3, 3, 2, 0, 0, 3, 2, 0, 3, 1,
#        3, 3, 0, 1, 0, 3, 2, 1, 2, 3, 1, 2, 3, 2, 0, 3, 3, 1, 2, 0, 2, 2,
#        2, 1, 3, 1, 2, 2, 2, 3, 1, 0, 0, 3, 3, 1, 2, 1, 2, 2, 2, 2, 0, 1,
#        2, 0, 0, 0, 2, 0, 3, 1, 0, 3, 1, 3, 3, 1, 1, 0, 0, 2, 3, 0, 0, 3,
#        2, 1, 0, 2, 1, 0, 1, 0, 0, 0, 1, 2, 3, 2, 3, 2, 1, 0, 1, 0, 3, 3,
#        2, 3, 3, 0, 3, 1, 0, 3, 1, 1, 2, 0, 0, 0, 3, 3, 0, 1, 1, 1, 0, 1,
#        0, 3, 1, 2, 0, 0, 1, 1, 0, 3, 3, 2, 2, 1, 1, 2, 3, 1, 2, 2, 0, 3,
#        2, 3, 0, 3, 3, 3, 2, 2, 2, 1, 0, 3, 3, 1, 2, 0, 1, 3, 3, 2, 2, 1,
#        1, 2, 0, 2, 1, 0, 0, 1, 2, 2, 0, 1, 2, 0, 2, 1, 3, 0, 3, 0, 3, 2,
#        1, 2, 2, 0, 0, 0, 2, 1, 3, 0, 3, 3, 1, 2, 2, 2, 0, 1, 3, 3, 3, 1,
#        0, 3, 1, 0, 1, 3, 3, 0, 0, 1, 0, 1, 1, 3, 1, 1, 2, 2, 0, 1, 2, 1,
#        1, 0, 3, 1, 0, 3, 3, 3, 3, 3, 1, 1, 1, 1, 3, 0, 1, 0, 2, 2, 0, 3,
#        3, 3, 2, 0, 2, 1, 0, 0, 2, 0, 3, 2, 0, 0, 0, 0, 0, 2, 2, 3, 2, 1,
#        3, 1, 0, 0, 1, 0, 0, 3, 0, 2, 1, 1, 1, 0, 2, 1, 3, 1, 2, 0, 1, 3,
#        2, 0, 2, 3, 2, 0, 3, 2, 2, 2, 2, 2, 3, 1, 1, 2, 1, 0, 0, 0, 1, 2,
#        2, 3, 1, 1, 1, 2, 0, 0, 0, 0, 1, 1, 1, 0, 1, 3, 2, 1, 0, 1, 1, 0,
#        1, 1, 3, 1, 0, 2, 0, 1, 1, 3, 3, 0, 1, 1, 2, 0, 0, 3, 3, 1, 0, 3,
#        2, 0, 2, 3, 3, 1, 3, 2, 0, 2, 3, 3, 1, 2, 2, 3, 1, 3, 3, 0, 3, 2,
#        2, 2, 3, 2, 1, 1, 1, 2, 3, 2, 2, 1, 2, 3, 1, 0, 0, 2, 1, 2, 1, 0,
#        3, 1, 1, 3, 0, 1, 3, 0, 3, 3, 2, 3, 3, 1, 0, 1, 3, 2, 0, 2, 2, 3,
#        0, 1, 1, 3, 3, 1, 1, 3, 1, 3, 3, 0, 2, 1, 3, 2, 3, 2, 3, 3, 1, 2,
#        1, 2, 1, 2, 3, 0, 2, 3, 0, 3, 3, 1, 1, 2, 1, 2, 2, 0, 0, 3, 3, 0,
#        3, 3, 2, 1, 0, 0, 2, 0, 2, 3, 1, 1, 0, 3, 0, 1, 2, 3, 2, 1, 3, 1,
#        1, 0, 2, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 3, 2, 2, 3, 1, 1, 1, 2, 1,
#        2, 0, 3, 0, 1, 3, 0, 2, 1, 2, 1, 0, 2, 1, 0, 0, 1, 3, 1, 2, 3, 0,
#        3, 2, 2, 1, 0, 1, 2, 1, 3, 3, 2, 2, 2, 2, 1, 0, 3, 1, 3, 0, 1, 2,
#        2, 0, 2, 2, 3, 1, 2, 1, 1, 1, 3, 3, 2, 2, 1, 3, 2, 2, 1, 1, 0, 3,
#        0, 3, 0, 1, 0, 1, 1, 2, 1, 2, 1, 2, 1, 0, 1, 2, 1, 3, 2, 3, 1, 3,
#        1, 0, 3, 2, 0, 0, 2, 1, 2, 0, 0, 0, 2, 1, 2, 3, 3, 2, 1, 0, 0, 0,
#        1, 0, 2, 0, 2, 1, 0, 3, 0, 3, 3, 2, 3, 1, 0, 2, 2, 3, 0, 2, 1, 0,
#        0, 3, 2, 2, 1, 1, 1, 2, 2, 2, 1, 1, 0, 0, 3, 0, 0, 3, 1, 3, 0, 0,
#        0, 0, 3, 2, 1, 3, 3, 0, 2, 2, 2, 1, 0, 3, 0, 2, 3, 0, 0, 0, 0, 0,
#        3, 0, 2, 3, 2, 3, 0, 3, 3, 0, 3, 1, 3, 1, 2, 2, 0, 3, 3, 1, 3, 2,
#        0, 2, 2, 3, 2, 0, 3, 3, 2, 0, 1, 1, 1, 0, 1, 1, 2, 0, 3, 2, 3, 3,
#        0, 0, 3, 2, 2, 1, 3, 3, 2, 1, 3, 2, 3, 2, 1, 1, 0, 3, 0, 2, 1, 1,
#        2, 0, 3, 0, 3, 0, 0, 3, 2, 3, 3, 3, 2, 0, 1, 0, 1, 2, 1, 0, 3, 3,
#        1, 2, 3, 1, 3, 0, 2, 3, 1, 1, 0, 0, 0, 2, 3, 2, 1, 1, 2, 1, 2, 0,
#        1, 2, 1, 2, 2, 1, 1, 3, 3, 2, 1, 1, 1, 0, 0, 0, 0, 1, 3, 0, 3, 1,
#        0, 3, 1, 1, 0, 3, 3, 3, 2, 1])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12, 8))
ax1.set_title('KMeans CHAMAA')
ax1.scatter(data[0][:,0], data[0][:,1], c=kmeans.labels_, cmap='rainbow')
ax2.set_title('Base original')
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')
